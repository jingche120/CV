# %% [markdown]
# 哈摟，各位資料科學家大家好，我是來自於台北市"頭期款不足"的阿宏，我想買房子很久了，但是不知道要買哪個地方，想先從內政部不動產交易時價登入資料中先了解行情，我現在手邊蒐集了台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)共四份資料，請各位資料科學家幫幫忙分析了。

# %% [markdown]
# # 1.不動產資料檔案讀取並串接

# %% [markdown]
# 資料分散在4個資料，先合併成一個資料方便後續分析，但是我發現有英文欄位跟中文欄位，留下中文刪除英文，並加入新的欄位用以分辨台北市Taipei、新北市New_Taipei、台中市Taichung、高雄市Kaohsiung

# %% [markdown]
# 1. 利用Pandas中的pd.read_csv()分別讀取A_lvr_land_A.csv、B_lvr_land_A.csv、E_lvr_land_A.csv、F_lvr_land_A.csv
# 2. 刪除csv中第二列英文翻譯，The villages and towns urban district,transaction sign,land sector position building sector house number plate,land shifting total area square meter,....
# 3. 生成city欄位其中以地區分類台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)
# 4. 將以上四份資料運用pd.concat()串接

# %%
import pandas as pd

# %%
#1.利用Pandas中的pd.read_csv()分別讀取A_lvr_land_A.csv、B_lvr_land_A.csv、E_lvr_land_A.csv、F_lvr_land_A.csv
data_a = pd.read_csv("a_lvr_land_a.csv")
data_b = pd.read_csv("b_lvr_land_a.csv")
data_e = pd.read_csv("e_lvr_land_a.csv")
data_f = pd.read_csv("f_lvr_land_a.csv")
# Out:
# C:\Users\sinon\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,7,14,15,16,17,18,21,22,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_a
# Out:
#                                        鄉鎮市區              交易標的  \
# 0     The villages and towns urban district  transaction sign
# 1                                       文山區         房地(土地+建物)
# 2                                       文山區         房地(土地+建物)
# 3                                       文山區      房地(土地+建物)+車位
# 4                                       中正區         房地(土地+建物)
# ...                                     ...               ...
# 7521                                    北投區      房地(土地+建物)+車位
# 7522                                    大安區         房地(土地+建物)
# 7523                                    大安區         房地(土地+建物)
# 7524                                    大安區         房地(土地+建物)
# 7525                                    大安區      房地(土地+建物)+車位
#
#                                                土地位置建物門牌  \
# 0     land sector position building sector house num...
# 1                                               保儀路１２９號
# 2                                         久康街１６９巷６號六樓之１
# 3                                        木柵路三段１６８號十五樓之１
# 4                                             惠安街５號五樓之６
# ...                                                 ...
# 7521                                          珠海路１１９號四樓
# 7522                                     安和路一段１０２巷１０號七樓
# 7523                                      信義路三段２０２號十樓之１
# 7524                                   信義路三段１３４巷４５弄６號四樓
# 7525                                        光復南路６８８號十二樓
#
#                                 土地移轉總面積平方公尺  \
# 0     land shifting total area square meter
# 1                                    1261.3
# 2                                     18.02
# 3                                     12.47
# 4                                     26.31
# ...                                     ...
# 7521                                  68.46
# 7522                                  26.22
# 7523                                   6.14
# 7524                                   36.8
# 7525                                   8.52
#
#                                                都市土地使用分區  \
# 0                 the use zoning or compiles and checks
# 1                                         都市：其他:第三種住宅區。
# 2                                         都市：其他:第三種住宅區。
# 3                                         都市：其他:第三種商業區。
# 4                             都市：其他:道路用地(公共設施用地)。63/1/3
# ...                                                 ...
# 7521                                      都市：其他:第二種住宅區。
# 7522                                      都市：其他:第四種住宅區。
# 7523  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第貳種商...
# 7524                         都市：其他:道路用地(公共設施用地)。60/7/13
# 7525  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...
#
#                                  非都市土地使用分區                非都市土地使用編定  \
# 0     the non-metropolis land use district  non-metropolis land use
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
# ...                                    ...                      ...
# 7521                                   NaN                      NaN
# 7522                                   NaN                      NaN
# 7523                                   NaN                      NaN
# 7524                                   NaN                      NaN
# 7525                                   NaN                      NaN
#
#                                交易年月日                   交易筆棟數            移轉層次  \
# 0     transaction year month and day  transaction pen number  shifting level
# 1                            1080423               土地3建物1車位0               全
# 2                            1090718               土地1建物1車位0              六層
# 3                            1090815               土地1建物1車位1             十五層
# 4                            1090722               土地2建物1車位0              五層
# ...                              ...                     ...             ...
# 7521                         1090913               土地1建物1車位1              四層
# 7522                         1091114               土地1建物1車位0              七層
# 7523                         1091111               土地1建物1車位0              十層
# 7524                         1091030               土地2建物1車位0              四層
# 7525                         1091120               土地3建物1車位1             十二層
#
#       ...                車位類別                           車位移轉總面積(平方公尺)  \
# 0     ...  the berth category  berth shifting total area square meter
# 1     ...                 NaN                                     0.0
# 2     ...                 NaN                                     0.0
# 3     ...                坡道平面                                   42.94
# 4     ...                 NaN                                     0.0
# ...   ...                 ...                                     ...
# 7521  ...                坡道平面                                   26.08
# 7522  ...                 NaN                                     0.0
# 7523  ...                 NaN                                     0.0
# 7524  ...                 NaN                                     0.0
# 7525  ...                坡道機械                                     0.0
#
#                           車位總價元            備註                   編號   主建物面積  \
# 0     the berth total price NTD      the note        serial number     NaN
# 1                             0           NaN  RPTOMLOLPHPFFAA58DA  245.48
# 2                             0           NaN  RPVNMLNJQHPFFAA48DA   38.13
# 3                             0           NaN  RPVOMLKLQHPFFAA48DA   91.37
# 4                             0         其他增建；  RPRNMLSLQHPFFAA78DA   66.17
# ...                         ...           ...                  ...     ...
# 7521                    2000000  陽台加蓋、雨遮其他增建；  RPUNMLSJKIPFFEA88EA   82.85
# 7522                          0           NaN  RPWOMLRKJIPFFFA56EA  110.28
# 7523                          0         陽台外推；  RPXOMLRKJIPFFFA66EA   56.19
# 7524                          0           NaN  RPOPMLRKJIPFFFA48EA   93.27
# 7525                    1500000           NaN  RPSNMLOKKIPFFFA48EA   58.02
#
#      附屬建物面積   陽台面積   電梯 移轉編號
# 0       NaN    NaN  NaN  NaN
# 1      0.00   0.00    無  NaN
# 2      5.87   4.74    有  NaN
# 3      8.07   7.14    有  NaN
# 4      0.00   3.58    有  NaN
# ...     ...    ...  ...  ...
# 7521  17.44   7.83    有  NaN
# 7522   0.00  18.80    有  NaN
# 7523   0.00   2.90    有  NaN
# 7524   0.00  17.35    有  NaN
# 7525   7.21   3.70    有  NaN
#
# [7526 rows x 33 columns]

# %%
#2.刪除csv中第二列英文翻譯，The villages and towns urban district,transaction sign,land sector position building sector house number plate,land shifting total area square meter,....
data_a = data_a.iloc[1:]
data_b = data_b.iloc[1:]
data_e = data_e.iloc[1:]
data_f = data_f.iloc[1:]

# %%
data_a
# Out:
#      鄉鎮市區          交易標的          土地位置建物門牌 土地移轉總面積平方公尺  \
# 1     文山區     房地(土地+建物)           保儀路１２９號      1261.3
# 2     文山區     房地(土地+建物)     久康街１６９巷６號六樓之１       18.02
# 3     文山區  房地(土地+建物)+車位    木柵路三段１６８號十五樓之１       12.47
# 4     中正區     房地(土地+建物)         惠安街５號五樓之６       26.31
# 5     中正區     房地(土地+建物)       重慶南路三段７１號四樓        36.0
# ...   ...           ...               ...         ...
# 7521  北投區  房地(土地+建物)+車位         珠海路１１９號四樓       68.46
# 7522  大安區     房地(土地+建物)    安和路一段１０２巷１０號七樓       26.22
# 7523  大安區     房地(土地+建物)     信義路三段２０２號十樓之１        6.14
# 7524  大安區     房地(土地+建物)  信義路三段１３４巷４５弄６號四樓        36.8
# 7525  大安區  房地(土地+建物)+車位       光復南路６８８號十二樓        8.52
#
#                                                都市土地使用分區 非都市土地使用分區 非都市土地使用編定  \
# 1                                         都市：其他:第三種住宅區。       NaN       NaN
# 2                                         都市：其他:第三種住宅區。       NaN       NaN
# 3                                         都市：其他:第三種商業區。       NaN       NaN
# 4                             都市：其他:道路用地(公共設施用地)。63/1/3       NaN       NaN
# 5                             都市：其他:道路用地(公共設施用地)。59/9/9       NaN       NaN
# ...                                                 ...       ...       ...
# 7521                                      都市：其他:第二種住宅區。       NaN       NaN
# 7522                                      都市：其他:第四種住宅區。       NaN       NaN
# 7523  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第貳種商...       NaN       NaN
# 7524                         都市：其他:道路用地(公共設施用地)。60/7/13       NaN       NaN
# 7525  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...       NaN       NaN
#
#         交易年月日      交易筆棟數 移轉層次  ...  車位類別 車位移轉總面積(平方公尺)    車位總價元            備註  \
# 1     1080423  土地3建物1車位0    全  ...   NaN           0.0        0           NaN
# 2     1090718  土地1建物1車位0   六層  ...   NaN           0.0        0           NaN
# 3     1090815  土地1建物1車位1  十五層  ...  坡道平面         42.94        0           NaN
# 4     1090722  土地2建物1車位0   五層  ...   NaN           0.0        0         其他增建；
# 5     1090808  土地2建物1車位0   四層  ...   NaN           0.0        0    陽台外推；其他增建；
# ...       ...        ...  ...  ...   ...           ...      ...           ...
# 7521  1090913  土地1建物1車位1   四層  ...  坡道平面         26.08  2000000  陽台加蓋、雨遮其他增建；
# 7522  1091114  土地1建物1車位0   七層  ...   NaN           0.0        0           NaN
# 7523  1091111  土地1建物1車位0   十層  ...   NaN           0.0        0         陽台外推；
# 7524  1091030  土地2建物1車位0   四層  ...   NaN           0.0        0           NaN
# 7525  1091120  土地3建物1車位1  十二層  ...  坡道機械           0.0  1500000           NaN
#
#                        編號   主建物面積 附屬建物面積   陽台面積 電梯 移轉編號
# 1     RPTOMLOLPHPFFAA58DA  245.48   0.00   0.00  無  NaN
# 2     RPVNMLNJQHPFFAA48DA   38.13   5.87   4.74  有  NaN
# 3     RPVOMLKLQHPFFAA48DA   91.37   8.07   7.14  有  NaN
# 4     RPRNMLSLQHPFFAA78DA   66.17   0.00   3.58  有  NaN
# 5     RPPNMLTLQHPFFAA68DA  106.57   4.81  16.47  無  NaN
# ...                   ...     ...    ...    ... ..  ...
# 7521  RPUNMLSJKIPFFEA88EA   82.85  17.44   7.83  有  NaN
# 7522  RPWOMLRKJIPFFFA56EA  110.28   0.00  18.80  有  NaN
# 7523  RPXOMLRKJIPFFFA66EA   56.19   0.00   2.90  有  NaN
# 7524  RPOPMLRKJIPFFFA48EA   93.27   0.00  17.35  有  NaN
# 7525  RPSNMLOKKIPFFFA48EA   58.02   7.21   3.70  有  NaN
#
# [7525 rows x 33 columns]

# %%
#3. 生成city欄位其中以地區分類台北市Taipei(A_lvr_land_A.csv)、新北市New_Taipei(F_lvr_land_A.csv)、台中市Taichung(B_lvr_land_A.csv)、高雄市Kaohsiung(E_lvr_land_A.csv)
data_a['city'] = "Taipei"
data_b['city'] = "New_Taipei"
data_e['city'] = "Taichung"
data_f['city'] = "Kaohsiung"

data_a
# Out:
# <ipython-input-6-ee94c4ed468f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_a['city'] = "Taipei"
#      鄉鎮市區          交易標的          土地位置建物門牌 土地移轉總面積平方公尺  \
# 1     文山區     房地(土地+建物)           保儀路１２９號      1261.3
# 2     文山區     房地(土地+建物)     久康街１６９巷６號六樓之１       18.02
# 3     文山區  房地(土地+建物)+車位    木柵路三段１６８號十五樓之１       12.47
# 4     中正區     房地(土地+建物)         惠安街５號五樓之６       26.31
# 5     中正區     房地(土地+建物)       重慶南路三段７１號四樓        36.0
# ...   ...           ...               ...         ...
# 7521  北投區  房地(土地+建物)+車位         珠海路１１９號四樓       68.46
# 7522  大安區     房地(土地+建物)    安和路一段１０２巷１０號七樓       26.22
# 7523  大安區     房地(土地+建物)     信義路三段２０２號十樓之１        6.14
# 7524  大安區     房地(土地+建物)  信義路三段１３４巷４５弄６號四樓        36.8
# 7525  大安區  房地(土地+建物)+車位       光復南路６８８號十二樓        8.52
#
#                                                都市土地使用分區 非都市土地使用分區 非都市土地使用編定  \
# 1                                         都市：其他:第三種住宅區。       NaN       NaN
# 2                                         都市：其他:第三種住宅區。       NaN       NaN
# 3                                         都市：其他:第三種商業區。       NaN       NaN
# 4                             都市：其他:道路用地(公共設施用地)。63/1/3       NaN       NaN
# 5                             都市：其他:道路用地(公共設施用地)。59/9/9       NaN       NaN
# ...                                                 ...       ...       ...
# 7521                                      都市：其他:第二種住宅區。       NaN       NaN
# 7522                                      都市：其他:第四種住宅區。       NaN       NaN
# 7523  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第貳種商...       NaN       NaN
# 7524                         都市：其他:道路用地(公共設施用地)。60/7/13       NaN       NaN
# 7525  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...       NaN       NaN
#
#         交易年月日      交易筆棟數 移轉層次  ... 車位移轉總面積(平方公尺)    車位總價元            備註  \
# 1     1080423  土地3建物1車位0    全  ...           0.0        0           NaN
# 2     1090718  土地1建物1車位0   六層  ...           0.0        0           NaN
# 3     1090815  土地1建物1車位1  十五層  ...         42.94        0           NaN
# 4     1090722  土地2建物1車位0   五層  ...           0.0        0         其他增建；
# 5     1090808  土地2建物1車位0   四層  ...           0.0        0    陽台外推；其他增建；
# ...       ...        ...  ...  ...           ...      ...           ...
# 7521  1090913  土地1建物1車位1   四層  ...         26.08  2000000  陽台加蓋、雨遮其他增建；
# 7522  1091114  土地1建物1車位0   七層  ...           0.0        0           NaN
# 7523  1091111  土地1建物1車位0   十層  ...           0.0        0         陽台外推；
# 7524  1091030  土地2建物1車位0   四層  ...           0.0        0           NaN
# 7525  1091120  土地3建物1車位1  十二層  ...           0.0  1500000           NaN
#
#                        編號   主建物面積 附屬建物面積   陽台面積 電梯 移轉編號    city
# 1     RPTOMLOLPHPFFAA58DA  245.48   0.00   0.00  無  NaN  Taipei
# 2     RPVNMLNJQHPFFAA48DA   38.13   5.87   4.74  有  NaN  Taipei
# 3     RPVOMLKLQHPFFAA48DA   91.37   8.07   7.14  有  NaN  Taipei
# 4     RPRNMLSLQHPFFAA78DA   66.17   0.00   3.58  有  NaN  Taipei
# 5     RPPNMLTLQHPFFAA68DA  106.57   4.81  16.47  無  NaN  Taipei
# ...                   ...     ...    ...    ... ..  ...     ...
# 7521  RPUNMLSJKIPFFEA88EA   82.85  17.44   7.83  有  NaN  Taipei
# 7522  RPWOMLRKJIPFFFA56EA  110.28   0.00  18.80  有  NaN  Taipei
# 7523  RPXOMLRKJIPFFFA66EA   56.19   0.00   2.90  有  NaN  Taipei
# 7524  RPOPMLRKJIPFFFA48EA   93.27   0.00  17.35  有  NaN  Taipei
# 7525  RPSNMLOKKIPFFFA48EA   58.02   7.21   3.70  有  NaN  Taipei
#
# [7525 rows x 34 columns]

# %%
#4. 將以上四份資料運用pd.concat()串接
all_data = pd.concat([data_a,data_b,data_e,data_f],axis=0)
all_data
# Out:
#       鄉鎮市區          交易標的        土地位置建物門牌 土地移轉總面積平方公尺  \
# 1      文山區     房地(土地+建物)         保儀路１２９號      1261.3
# 2      文山區     房地(土地+建物)   久康街１６９巷６號六樓之１       18.02
# 3      文山區  房地(土地+建物)+車位  木柵路三段１６８號十五樓之１       12.47
# 4      中正區     房地(土地+建物)       惠安街５號五樓之６       26.31
# 5      中正區     房地(土地+建物)     重慶南路三段７１號四樓        36.0
# ...    ...           ...             ...         ...
# 16830  鶯歌區            土地      南靖段817-1地號        9.17
# 16831  鶯歌區            土地      南靖段817-1地號        6.57
# 16832  鶯歌區            土地      南靖段818-1地號      101.78
# 16833  鶯歌區            土地      南靖段817-1地號        9.17
# 16834  鶯歌區            土地      南靖段818-1地號         2.6
#
#                         都市土地使用分區 非都市土地使用分區 非都市土地使用編定    交易年月日      交易筆棟數 移轉層次  \
# 1                  都市：其他:第三種住宅區。       NaN       NaN  1080423  土地3建物1車位0    全
# 2                  都市：其他:第三種住宅區。       NaN       NaN  1090718  土地1建物1車位0   六層
# 3                  都市：其他:第三種商業區。       NaN       NaN  1090815  土地1建物1車位1  十五層
# 4      都市：其他:道路用地(公共設施用地)。63/1/3       NaN       NaN  1090722  土地2建物1車位0   五層
# 5      都市：其他:道路用地(公共設施用地)。59/9/9       NaN       NaN  1090808  土地2建物1車位0   四層
# ...                          ...       ...       ...      ...        ...  ...
# 16830                        NaN     一般農業區      交通用地  1090930  土地2建物0車位0  NaN
# 16831                        NaN     一般農業區      交通用地  1090930  土地1建物0車位0  NaN
# 16832                        NaN     一般農業區      交通用地  1090930  土地3建物0車位0  NaN
# 16833                        NaN     一般農業區      交通用地  1090930  土地2建物0車位0  NaN
# 16834                        NaN     一般農業區      交通用地  1090930  土地1建物0車位0  NaN
#
#        ... 車位移轉總面積(平方公尺) 車位總價元          備註                   編號   主建物面積  \
# 1      ...           0.0     0         NaN  RPTOMLOLPHPFFAA58DA  245.48
# 2      ...           0.0     0         NaN  RPVNMLNJQHPFFAA48DA   38.13
# 3      ...         42.94     0         NaN  RPVOMLKLQHPFFAA48DA   91.37
# 4      ...           0.0     0       其他增建；  RPRNMLSLQHPFFAA78DA   66.17
# 5      ...           0.0     0  陽台外推；其他增建；  RPPNMLTLQHPFFAA68DA  106.57
# ...    ...           ...   ...         ...                  ...     ...
# 16830  ...           0.0     0       協議價購；  RPSNMLSKIIPFFIF76DA    0.00
# 16831  ...           0.0     0       協議價購；  RPTNMLSKIIPFFIF86DA    0.00
# 16832  ...           0.0     0       協議價購；  RPUNMLSKIIPFFIF96DA    0.00
# 16833  ...           0.0     0       協議價購；  RPVNMLSKIIPFFIF07DA    0.00
# 16834  ...           0.0     0       協議價購；  RPWNMLSKIIPFFIF17DA    0.00
#
#       附屬建物面積   陽台面積 電梯 移轉編號       city
# 1       0.00   0.00  無  NaN     Taipei
# 2       5.87   4.74  有  NaN     Taipei
# 3       8.07   7.14  有  NaN     Taipei
# 4       0.00   3.58  有  NaN     Taipei
# 5       4.81  16.47  無  NaN     Taipei
# ...      ...    ... ..  ...        ...
# 16830   0.00   0.00  無  NaN  Kaohsiung
# 16831   0.00   0.00  無  NaN  Kaohsiung
# 16832   0.00   0.00  無  NaN  Kaohsiung
# 16833   0.00   0.00  無  NaN  Kaohsiung
# 16834   0.00   0.00  無  NaN  Kaohsiung
#
# [53009 rows x 34 columns]

# %% [markdown]
# # 2. 資料清理與切片

# %% [markdown]
# 因為我是想買來住的房子，所以幫忙刪除住宿用途以外的資料，並且限制
# 1. 交易年月日，限制在109年
# 2. 建物現況格局-房，1~5間
# 3. 建物現況格局-廳，1~2廳

# %% [markdown]
# 以下columns_mapping、analysis_columns、columns_type提供給資料科學家配合使用
# 1. 利用.rename()並配合以下columns_mapping，將原中文欄位名稱改為英文方便之後分析
# 2. 取出主要用途(main_use)為'住家用'以及都市土地使用分區(use_zoning)為'住'的資料並針對以下欄位analysis_columns做分析並去除na值
#    (提示:先取完之後再.dropna())
# 3. 觀察欄位資料型態，並利用.astype()搭配以下提供的columns_type做欄位型態轉換
# 4. 做資料切片將<br>
#     新增欄位交易年月日(tx_dt_year)，從交易年月日(tx_dt)萃取出年份<br>
#     1.交易年月日(tx_dt_year)，限制在109年<br>
#     2.建物現況格局-房(room_number)，限制在1到5間<br>
#     3.建物現況格局-廳(hall_number)，限制在1到2廳<br>
#     4.最後運用.reset_index()重新定義索引

# %%
columns_mapping = {'鄉鎮市區':'towns',
'交易標的':'transaction_sign',
'土地區段位置建物區段門牌':'house_number',
'土地移轉總面積平方公尺':'land_area_square_meter', 
'都市土地使用分區':'use_zoning', 
'非都市土地使用分區':'land_use_district',
'非都市土地使用編定':'land_use',
'交易年月日':'tx_dt', 
 '交易筆棟數':'transaction_pen_number', 
 '土地位置建物門牌':'Land location building house number',
 '移轉層次':'shifting_level', 
 '總樓層數':'total_floor_number', 
 '建物型態':'building_state', 
 '主要用途':'main_use', 
 '主要建材':'main_materials',
 '建築完成年月':'complete_date', 
 '建物移轉總面積平方公尺':'building_area_square_meter', 
 '建物現況格局-房':'room_number', 
 '建物現況格局-廳':'hall_number', 
 '建物現況格局-衛':'health_number', 
'建物現況格局-隔間':'compartmented_number', 
 '有無管理組織':'manages', 
 '總價元':'total_price', 
 '單價元平方公尺':'unit_price', 
 '車位類別':'berth_category', 
 '車位移轉總面積(平方公尺)':'berth_area_square_meter',
'車位總價元':'berth_price', 
 '備註':'note', 
 '編號':'serial_number', 
 '主建物面積':'main_building_area', 
 '附屬建物面積':'auxiliary_building_area', 
 '陽台面積':'balcony_area', 
 '電梯':'elevator'
                  }
analysis_columns = ['city','towns','main_use','use_zoning','total_price','building_area_square_meter',
                                     'main_building_area',
                                     'tx_dt','unit_price','room_number','hall_number','health_number']
columns_type = {'total_price': 'int','unit_price':'float','building_area_square_meter':'float',
                                      'main_building_area': 'float',
                                      'room_number': 'int','hall_number': 'int','health_number': 'int'}

# %%
#1. 利用.rename()並配合以下columns_mapping，將原中文欄位名稱改為英文方便之後分析
analysis_data = all_data.rename(columns=columns_mapping)
analysis_data['main_use'].head(20)
# Out:
# 1         住家用
# 2     見其他登記事項
# 3     見其他登記事項
# 4     見其他登記事項
# 5         住家用
# 6         住家用
# 7         住家用
# 8     見其他登記事項
# 9     見其他登記事項
# 10        商業用
# 11        住家用
# 12    見其他登記事項
# 13        住家用
# 14        住家用
# 15        住家用
# 16        住家用
# 17        住家用
# 18        住商用
# 19        住家用
# 20        住家用
# Name: main_use, dtype: object

# %%
analysis_data['use_zoning'].str.contains('住')
# Out:
# 1         True
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 16830      NaN
# 16831      NaN
# 16832      NaN
# 16833      NaN
# 16834      NaN
# Name: use_zoning, Length: 53009, dtype: object

# %%
#2. 取出主要用途(main_use)為'住家用'以及都市土地使用分區(use_zoning)為'住'的資料並針對以下欄位analysis_columns做分析並去除na值 (提示:先取完之後再.dropna())
#   (提示:先取完之後再.dropna())
analysis_data = analysis_data.loc[(analysis_data.main_use=='住家用')&(analysis_data['use_zoning'].str.contains('住')),analysis_columns].dropna()
print(analysis_columns)
analysis_data
# Out:
# ['city', 'towns', 'main_use', 'use_zoning', 'total_price', 'building_area_square_meter', 'main_building_area', 'tx_dt', 'unit_price', 'room_number', 'hall_number', 'health_number']
#             city towns main_use     use_zoning total_price  \
# 1         Taipei   文山區      住家用  都市：其他:第三種住宅區。   523060000
# 11        Taipei   中正區      住家用  都市：其他:第三種住宅區。    10400000
# 13        Taipei   中正區      住家用  都市：其他:第三種住宅區。    35800000
# 19        Taipei   萬華區      住家用  都市：其他:第三種住宅區。    15800000
# 27        Taipei   內湖區      住家用  都市：其他:第三種住宅區。    12800000
# ...          ...   ...      ...            ...         ...
# 16819  Kaohsiung   鶯歌區      住家用      都市：其他:住宅區     3000000
# 16820  Kaohsiung   三峽區      住家用      都市：其他:住宅區    12460000
# 16824  Kaohsiung   三峽區      住家用      都市：其他:住宅區     9000000
# 16825  Kaohsiung   三峽區      住家用      都市：其他:住宅區     5000000
# 16827  Kaohsiung   鶯歌區      住家用   都市：其他:第一種住宅區     5250000
#
#       building_area_square_meter  main_building_area    tx_dt unit_price  \
# 1                         245.48              245.48  1080423    2130764
# 11                         34.63               33.00  1090630     300318
# 13                         99.86               99.86  1090719     358502
# 19            104.72999999999999               70.63  1090704     150864
# 27             75.52000000000001               38.10  1090719     169492
# ...                          ...                 ...      ...        ...
# 16819                       82.0               71.88  1091107    36585.0
# 16820                     131.68               88.84  1091025    94623.0
# 16824                     109.75               46.42  1091105    82005.0
# 16825                      42.62               22.71  1091104   117316.0
# 16827                     117.14               74.11  1091029    44818.0
#
#       room_number hall_number health_number
# 1               0           0             0
# 11              0           1             1
# 13              3           2             2
# 19              3           2             2
# 27              1           1             1
# ...           ...         ...           ...
# 16819           3           2             1
# 16820           3           2             2
# 16824           2           2             1
# 16825           1           0             1
# 16827           3           2             2
#
# [14060 rows x 12 columns]

# %%
#3. 觀察欄位資料型態，並利用.astype()搭配以下提供的columns_type做欄位型態轉換
columns_type = {'total_price': 'int','unit_price':'float','building_area_square_meter':'float',
                                      'main_building_area': 'float',
                                      'room_number': 'int','hall_number': 'int','health_number': 'int'}

analysis_data.info()
analysis_data = analysis_data.astype(columns_type)
analysis_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14060 entries, 1 to 16827
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        14060 non-null  object
#  1   towns                       14060 non-null  object
#  2   main_use                    14060 non-null  object
#  3   use_zoning                  14060 non-null  object
#  4   total_price                 14060 non-null  object
#  5   building_area_square_meter  14060 non-null  object
#  6   main_building_area          14060 non-null  float64
#  7   tx_dt                       14060 non-null  object
#  8   unit_price                  14060 non-null  object
#  9   room_number                 14060 non-null  object
#  10  hall_number                 14060 non-null  object
#  11  health_number               14060 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14060 entries, 1 to 16827
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        14060 non-null  object
#  1   towns                       14060 non-null  object
#  2   main_use                    14060 non-null  object
#  3   use_zoning                  14060 non-null  object
#  4   total_price                 14060 non-null  int32
#  5   building_area_square_meter  14060 non-null  float64
#  6   main_building_area          14060 non-null  float64
#  7   tx_dt                       14060 non-null  object
#  8   unit_price                  14060 non-null  float64
#  9   room_number                 14060 non-null  int32
#  10  hall_number                 14060 non-null  int32
#  11  health_number               14060 non-null  int32
# dtypes: float64(3), int32(4), object(5)
# memory usage: 1.2+ MB

# %%
#4. 做資料切片將
#     新增欄位交易年月日(tx_dt_year)，從交易年月日(tx_dt)萃取出年份
#     1.交易年月日(tx_dt_year)，限制在109年
#     2.建物現況格局-房(room_number)，限制在1到5間
#     3.建物現況格局-廳(hall_number)，限制在1到2廳
#     4.最後運用.reset_index()重新定義索引

analysis_data['tx_dt_year'] = analysis_data['tx_dt'].apply(lambda x: int(x)//10000)
analysis_data  = analysis_data.loc[(analysis_data.tx_dt_year>=109)&
                   (analysis_data.room_number>=1)&
                   (analysis_data.room_number<=5)&
                   (analysis_data.hall_number>=1)&
                   (analysis_data.hall_number<=2)]
analysis_data = analysis_data.reset_index(drop=True)
analysis_data
# Out:
#             city towns main_use  \
# 0         Taipei   中正區      住家用
# 1         Taipei   萬華區      住家用
# 2         Taipei   內湖區      住家用
# 3         Taipei   內湖區      住家用
# 4         Taipei   中山區      住家用
# ...          ...   ...      ...
# 12280  Kaohsiung   三峽區      住家用
# 12281  Kaohsiung   鶯歌區      住家用
# 12282  Kaohsiung   三峽區      住家用
# 12283  Kaohsiung   三峽區      住家用
# 12284  Kaohsiung   鶯歌區      住家用
#
#                                               use_zoning  total_price  \
# 0                                          都市：其他:第三種住宅區。     35800000
# 1                                          都市：其他:第三種住宅區。     15800000
# 2                                          都市：其他:第三種住宅區。     12800000
# 3                                          都市：其他:第三種住宅區。     43380000
# 4      都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...      5600000
# ...                                                  ...          ...
# 12280                                          都市：其他:住宅區     14880000
# 12281                                          都市：其他:住宅區      3000000
# 12282                                          都市：其他:住宅區     12460000
# 12283                                          都市：其他:住宅區      9000000
# 12284                                       都市：其他:第一種住宅區      5250000
#
#        building_area_square_meter  main_building_area    tx_dt  unit_price  \
# 0                           99.86               99.86  1090719    358502.0
# 1                          104.73               70.63  1090704    150864.0
# 2                           75.52               38.10  1090719    169492.0
# 3                          257.68              110.60  1090807    168348.0
# 4                           37.81               26.51  1090822    148109.0
# ...                           ...                 ...      ...         ...
# 12280                      156.53               78.82  1091106     95062.0
# 12281                       82.00               71.88  1091107     36585.0
# 12282                      131.68               88.84  1091025     94623.0
# 12283                      109.75               46.42  1091105     82005.0
# 12284                      117.14               74.11  1091029     44818.0
#
#        room_number  hall_number  health_number  tx_dt_year
# 0                3            2              2         109
# 1                3            2              2         109
# 2                1            1              1         109
# 3                3            2              2         109
# 4                1            1              1         109
# ...            ...          ...            ...         ...
# 12280            3            2              2         109
# 12281            3            2              1         109
# 12282            3            2              2         109
# 12283            2            2              1         109
# 12284            3            2              2         109
#
# [12285 rows x 13 columns]

# %% [markdown]
# # 3. 建立自定義特徵加入分析

# %% [markdown]
# 以台灣來說大家都是以坪為單位計算使用面積，應該是不會問說你家有幾平方公尺吧?，但是偏偏資料中沒有以坪為單位計算，所以接下來請各位幫忙產生新的欄位以坪為單位計算面積，轉換公式我也幫你找好了，在下面的定義。<br>
# 定義 : 1平方公尺相當於0.3025坪 <br>
# 建立新特徵
# 1. 建物移轉總面積坪(building_area_square_feet) : 建物移轉總面積平方公尺\*0.3025
# 2. 主建物面積坪(main_building_area_square_feet) : 主建物面積\*0.3025
# 3. 單價元坪(unit_price_square_feet) : 單價元平方公尺/0.3025

# %% [markdown]
# 可以利用.describe()做一下資料觀察，是否有奇怪的資料?<br>
# 如果有請將資料移除，並說明為什麼移除此資料?<br>
# 移除後再用.describe()觀察是否還有奇怪的資料?

# %%
# 建立新特徵
# 1. 建物移轉總面積坪(building_area_square_feet) : 建物移轉總面積平方公尺*0.3025
# 2. 主建物面積坪(main_building_area_square_feet) : 主建物面積*0.3025
# 3. 單價元坪(unit_price_square_feet) : 單價元平方公尺/0.3025
analysis_data['building_area_square_feet'] = analysis_data['building_area_square_meter']*0.3025
analysis_data['main_building_area_square_feet'] = analysis_data['main_building_area']*0.3025
analysis_data['unit_price_square_feet'] = analysis_data['unit_price']/0.3025

# %%
# 可以利用.describe()做一下資料觀察，是否有奇怪的資料?
# 如果有請將資料移除，並說明為什麼移除此資料?
analysis_data = analysis_data.loc[(analysis_data.total_price!=0)&(analysis_data.main_building_area!=0)]
analysis_data.describe()
# Out:
#         total_price  building_area_square_meter  main_building_area  \
# count  1.227600e+04                12276.000000        12276.000000
# mean   1.277059e+07                  124.894876           83.307290
# std    1.323579e+07                   63.365513           37.884626
# min    6.300000e+04                    1.050000            1.050000
# 25%    6.150000e+06                   84.000000           61.490000
# 50%    9.439000e+06                  112.240000           79.400000
# 75%    1.500000e+07                  152.532500           97.260000
# max    4.250000e+08                  756.630000          656.980000
#
#          unit_price   room_number   hall_number  health_number  tx_dt_year  \
# count   12276.00000  12276.000000  12276.000000   12276.000000     12276.0
# mean   103347.10321      2.851662      1.788856       1.740388       109.0
# std     64452.33158      0.905690      0.408137       0.689615         0.0
# min      5700.00000      1.000000      1.000000       0.000000       109.0
# 25%     57114.50000      2.000000      2.000000       1.000000       109.0
# 50%     86957.00000      3.000000      2.000000       2.000000       109.0
# 75%    129655.50000      3.000000      2.000000       2.000000       109.0
# max    798611.00000      5.000000      2.000000       7.000000       109.0
#
#        building_area_square_feet  main_building_area_square_feet  \
# count               12276.000000                    12276.000000
# mean                   37.780700                       25.200455
# std                    19.168068                       11.460099
# min                     0.317625                        0.317625
# 25%                    25.410000                       18.600725
# 50%                    33.952600                       24.018500
# 75%                    46.141081                       29.421150
# max                   228.880575                      198.736450
#
#        unit_price_square_feet
# count            1.227600e+04
# mean             3.416433e+05
# std              2.130656e+05
# min              1.884298e+04
# 25%              1.888083e+05
# 50%              2.874612e+05
# 75%              4.286132e+05
# max              2.640036e+06

# %%
# 移除後再用.describe()觀察是否還有奇怪的資料?

#無

# %% [markdown]
# # 4. 找出台北市時價登入總價高度相關的變數

# %% [markdown]
# 阿宏我是台北人他想找出影響台北市總價、單價元坪的因子<br>
# 相關係數0.3以下為低相關，0.3\~0.7為中等相關，0.7以上為高度相關<br>
# 1. 資料切片切出city欄位為台北市的資料，並找出時價登入總價(total_price)高度相關的變數
# 2. 資料切片切出city欄位為台北市的資料，找出單價元坪(unit_price_square_feet)高度相關的變數

# %%
analysis_data.head(50)
# Out:
#       city towns main_use                                         use_zoning  \
# 0   Taipei   中正區      住家用                                      都市：其他:第三種住宅區。
# 1   Taipei   萬華區      住家用                                      都市：其他:第三種住宅區。
# 2   Taipei   內湖區      住家用                                      都市：其他:第三種住宅區。
# 3   Taipei   內湖區      住家用                                      都市：其他:第三種住宅區。
# 4   Taipei   中山區      住家用  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...
# 5   Taipei   松山區      住家用                                      都市：其他:第三種住宅區。
# 6   Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 7   Taipei   信義區      住家用                             都市：其他:第三之一種住宅區及第三種住宅區。
# 8   Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 9   Taipei   南港區      住家用                                  都市：其他:住宅區(供住宅使用)。
# 10  Taipei   南港區      住家用                                      都市：其他:第三種住宅區。
# 11  Taipei   北投區      住家用                                      都市：其他:第三種住宅區。
# 12  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 13  Taipei   北投區      住家用                                      都市：其他:第三種住宅區。
# 14  Taipei   北投區      住家用                                      都市：其他:第三種住宅區。
# 15  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 16  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 17  Taipei   士林區      住家用  都市：其他:第參種商業區(依都市計畫說明書圖規定辦理，始得作第參種商業區使用)(原屬第參種住...
# 18  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 19  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 20  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 21  Taipei   大安區      住家用                                      都市：其他:第三種住宅區。
# 22  Taipei   大安區      住家用                                      都市：其他:第四種住宅區。
# 23  Taipei   大安區      住家用                                      都市：其他:第三種住宅區。
# 24  Taipei   文山區      住家用                                      都市：其他:第三種住宅區。
# 25  Taipei   文山區      住家用                                      都市：其他:第三種住宅區。
# 26  Taipei   文山區      住家用                                      都市：其他:第三種住宅區。
# 27  Taipei   中正區      住家用                                      都市：其他:第三種住宅區。
# 28  Taipei   大同區      住家用                                      都市：其他:第四種住宅區。
# 29  Taipei   內湖區      住家用                                      都市：其他:第三種住宅區。
# 30  Taipei   南港區      住家用                                      都市：其他:第三種住宅區。
# 31  Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 32  Taipei   松山區      住家用                                      都市：其他:第三種住宅區。
# 33  Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 34  Taipei   松山區      住家用                             都市：其他:住宅用地(民生社區特定專用區)。
# 35  Taipei   松山區      住家用                                      都市：其他:第三種住宅區。
# 36  Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 37  Taipei   松山區      住家用                                      都市：其他:第三種住宅區。
# 38  Taipei   松山區      住家用                                      都市：其他:第三種住宅區。
# 39  Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 40  Taipei   信義區      住家用                                      都市：其他:第三種住宅區。
# 41  Taipei   南港區      住家用                                      都市：其他:第三種住宅區。
# 42  Taipei   士林區      住家用                                      都市：其他:第二種住宅區。
# 43  Taipei   士林區      住家用                                      都市：其他:第二種住宅區。
# 44  Taipei   北投區      住家用                                      都市：其他:第三種住宅區。
# 45  Taipei   士林區      住家用                                      都市：其他:第三種住宅區。
# 46  Taipei   大安區      住家用                             都市：其他:第三之一種住宅區及第三種住宅區。
# 47  Taipei   大安區      住家用                                      都市：其他:第三種住宅區。
# 48  Taipei   大安區      住家用                                      都市：其他:第三種住宅區。
# 49  Taipei   大安區      住家用                                      都市：其他:第三種住宅區。
#
#     total_price  building_area_square_meter  main_building_area    tx_dt  \
# 0      35800000                       99.86               99.86  1090719
# 1      15800000                      104.73               70.63  1090704
# 2      12800000                       75.52               38.10  1090719
# 3      43380000                      257.68              110.60  1090807
# 4       5600000                       37.81               26.51  1090822
# 5      23100000                      121.07               79.41  1090724
# 6      18980000                       67.94               37.67  1090805
# 7      19360000                       97.84               76.88  1090721
# 8      17000000                      102.79               86.03  1090430
# 9      20080000                      110.91               60.67  1090811
# 10     12380000                      115.55               96.22  1090725
# 11     13800000                       98.14               74.62  1090716
# 12     17800000                      121.87              105.99  1090717
# 13     30000000                      188.35               89.84  1090817
# 14      8660000                       59.68               59.68  1090728
# 15     13200000                       94.04               75.43  1090703
# 16      5320000                       42.80               39.60  1090714
# 17     29500000                      116.03               60.39  1090817
# 18     14100000                      107.77               95.93  1090810
# 19      6880000                       57.48               57.48  1090810
# 20      5000000                       61.36               49.85  1090819
# 21     22650000                       98.19               84.84  1090820
# 22     28500000                      112.89               82.95  1090817
# 23     45880000                      214.05              214.05  1090317
# 24     13600000                       80.73               48.98  1090725
# 25     13380000                      108.82               63.90  1090805
# 26      9000000                       86.33               86.33  1090811
# 27      9900000                       39.32               12.53  1090731
# 28      9660000                       79.61               64.19  1090822
# 29     23000000                      139.08               68.62  1090810
# 30     12050000                       97.14               80.46  1090802
# 31     18200000                       77.33               57.07  1090803
# 32     16000000                       94.31               94.32  1090807
# 33     30000000                      217.13              102.85  1090812
# 34     28800000                      119.55              119.55  1090822
# 35     34700000                      147.17              125.90  1090723
# 36     12300000                       65.10               65.10  1090801
# 37      7930000                       34.77               13.68  1090820
# 38     20000000                      144.22              114.98  1090612
# 39     18700000                      117.10               83.17  1090805
# 40     14500000                       68.88               68.88  1090809
# 41      8380000                       77.00               77.00  1090729
# 42     19800000                      120.86               93.96  1090812
# 43     27800000                      173.01               89.46  1090619
# 44     13600000                      109.60              109.60  1090720
# 45      8860000                       85.87               67.34  1090809
# 46     40980000                      169.31              128.87  1090704
# 47     59120000                      176.35               80.72  1090816
# 48     16660000                       74.73               64.77  1090724
# 49     22000000                      101.08               68.77  1090824
#
#     unit_price  room_number  hall_number  health_number  tx_dt_year  \
# 0     358502.0            3            2              2         109
# 1     150864.0            3            2              2         109
# 2     169492.0            1            1              1         109
# 3     168348.0            3            2              2         109
# 4     148109.0            1            1              1         109
# 5     190799.0            3            2              2         109
# 6     279364.0            1            2              1         109
# 7     197874.0            2            2              1         109
# 8     165386.0            3            2              3         109
# 9     181048.0            2            2              1         109
# 10    107140.0            3            2              2         109
# 11    140615.0            3            2              2         109
# 12    146057.0            3            2              2         109
# 13    159278.0            3            2              2         109
# 14    145107.0            2            1              1         109
# 15    140366.0            3            2              1         109
# 16    124299.0            3            1              1         109
# 17    273159.0            2            2              1         109
# 18    130834.0            3            2              2         109
# 19    119694.0            2            2              1         109
# 20     81486.0            3            2              2         109
# 21    230675.0            3            2              1         109
# 22    252458.0            3            2              2         109
# 23    214342.0            4            2              3         109
# 24    168463.0            3            2              1         109
# 25    122944.0            3            2              2         109
# 26    104251.0            3            2              1         109
# 27    337214.0            1            1              1         109
# 28    121342.0            3            2              1         109
# 29    165372.0            3            2              2         109
# 30    124048.0            3            2              2         109
# 31    235355.0            2            2              1         109
# 32    169653.0            2            2              2         109
# 33    138166.0            2            2              2         109
# 34    240903.0            3            1              1         109
# 35    235782.0            4            2              2         109
# 36    188940.0            3            2              1         109
# 37    228070.0            1            1              1         109
# 38    138677.0            3            2              2         109
# 39    159693.0            3            2              2         109
# 40    210511.0            2            1              1         109
# 41    108831.0            3            2              1         109
# 42    163826.0            3            2              2         109
# 43    158168.0            3            2              2         109
# 44    124088.0            3            2              2         109
# 45    103179.0            4            2              1         109
# 46    242041.0            3            2              2         109
# 47    383245.0            3            2              2         109
# 48    222936.0            4            2              1         109
# 49    217649.0            3            2              1         109
#
#     building_area_square_feet  main_building_area_square_feet  \
# 0                   30.207650                       30.207650
# 1                   31.680825                       21.365575
# 2                   22.844800                       11.525250
# 3                   77.948200                       33.456500
# 4                   11.437525                        8.019275
# 5                   36.623675                       24.021525
# 6                   20.551850                       11.395175
# 7                   29.596600                       23.256200
# 8                   31.093975                       26.024075
# 9                   33.550275                       18.352675
# 10                  34.953875                       29.106550
# 11                  29.687350                       22.572550
# 12                  36.865675                       32.061975
# 13                  56.975875                       27.176600
# 14                  18.053200                       18.053200
# 15                  28.447100                       22.817575
# 16                  12.947000                       11.979000
# 17                  35.099075                       18.267975
# 18                  32.600425                       29.018825
# 19                  17.387700                       17.387700
# 20                  18.561400                       15.079625
# 21                  29.702475                       25.664100
# 22                  34.149225                       25.092375
# 23                  64.750125                       64.750125
# 24                  24.420825                       14.816450
# 25                  32.918050                       19.329750
# 26                  26.114825                       26.114825
# 27                  11.894300                        3.790325
# 28                  24.082025                       19.417475
# 29                  42.071700                       20.757550
# 30                  29.384850                       24.339150
# 31                  23.392325                       17.263675
# 32                  28.528775                       28.531800
# 33                  65.681825                       31.112125
# 34                  36.163875                       36.163875
# 35                  44.518925                       38.084750
# 36                  19.692750                       19.692750
# 37                  10.517925                        4.138200
# 38                  43.626550                       34.781450
# 39                  35.422750                       25.158925
# 40                  20.836200                       20.836200
# 41                  23.292500                       23.292500
# 42                  36.560150                       28.422900
# 43                  52.335525                       27.061650
# 44                  33.154000                       33.154000
# 45                  25.975675                       20.370350
# 46                  51.216275                       38.983175
# 47                  53.345875                       24.417800
# 48                  22.605825                       19.592925
# 49                  30.576700                       20.802925
#
#     unit_price_square_feet
# 0             1.185131e+06
# 1             4.987240e+05
# 2             5.603041e+05
# 3             5.565223e+05
# 4             4.896165e+05
# 5             6.307405e+05
# 6             9.235174e+05
# 7             6.541289e+05
# 8             5.467306e+05
# 9             5.985058e+05
# 10            3.541818e+05
# 11            4.648430e+05
# 12            4.828331e+05
# 13            5.265388e+05
# 14            4.796926e+05
# 15            4.640198e+05
# 16            4.109058e+05
# 17            9.030050e+05
# 18            4.325091e+05
# 19            3.956826e+05
# 20            2.693752e+05
# 21            7.625620e+05
# 22            8.345719e+05
# 23            7.085686e+05
# 24            5.569025e+05
# 25            4.064264e+05
# 26            3.446314e+05
# 27            1.114757e+06
# 28            4.011306e+05
# 29            5.466843e+05
# 30            4.100760e+05
# 31            7.780331e+05
# 32            5.608364e+05
# 33            4.567471e+05
# 34            7.963736e+05
# 35            7.794446e+05
# 36            6.245950e+05
# 37            7.539504e+05
# 38            4.584364e+05
# 39            5.279107e+05
# 40            6.959041e+05
# 41            3.597719e+05
# 42            5.415736e+05
# 43            5.228694e+05
# 44            4.102083e+05
# 45            3.410876e+05
# 46            8.001355e+05
# 47            1.266926e+06
# 48            7.369785e+05
# 49            7.195008e+05

# %%
# 阿宏我是台北人他想找出影響台北市總價、單價元坪的因子
# 1. 資料切片切出city欄位為台北市的資料，並找出時價登入總價(total_price)高度相關的變數
# 2. 資料切片切出city欄位為台北市的資料，找出單價元坪(unit_price_square_feet)高度相關的變數
analysis_data.loc[analysis_data['city']=='Taipei'].corr()[['total_price','unit_price_square_feet']]
# Out:
#                                 total_price  unit_price_square_feet
# total_price                        1.000000                0.560309
# building_area_square_meter         0.809504                0.156678
# main_building_area                 0.649019                0.045158
# unit_price                         0.560309                1.000000
# room_number                        0.308173               -0.109741
# hall_number                        0.242998               -0.087699
# health_number                      0.524631                0.062207
# tx_dt_year                              NaN                     NaN
# building_area_square_feet          0.809504                0.156678
# main_building_area_square_feet     0.649019                0.045158
# unit_price_square_feet             0.560309                1.000000

# %% [markdown]
# 1.由相關係數可以看出，與總價(total_price)高度相關的變數，有'building_area_square_meter','building_area_square_feet'<br>
# 2.由相關係數可以看出，與單價元坪(unit_price_square_feet)高度相關的變數，有'unit_price'

# %% [markdown]
# # 5. 資料視覺化並解釋

# %% [markdown]
# 我想要以視覺化的方式來看房價資料，並且請各位資料科學家解釋圖表給阿宏我知道
# 1. 以城市(city)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區
# 2. 進一步對台北市的資料做圖，以建物現況格局-房(room_number)為x軸，以總價元(total_price)為y軸畫出boxplot，並找出總價元(total_price)中位數最高的房間數。hint:資料切片找出city欄位為台北市的資料，再進一步畫圖
# 3. 對台北市的資料做圖，先將地區(twons)做編碼在進行，再以地區(twon)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區。hint:運用LabelEncoder()對地區(twons)做編碼，運用.inverse_transform()反查編碼的地區

# %%
#1. 以城市(city)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區
import matplotlib.pyplot as plt
plt.bar(analysis_data['city'],analysis_data['unit_price_square_feet'])
plt.xlabel('city')
plt.ylabel('unit_price_square_feet')
plt.show()

# %%
analysis_data.boxplot(column=['unit_price_square_feet'],by='city',figsize=(16,6))
# Out:
# <AxesSubplot:title={'center':'unit_price_square_feet'}, xlabel='city'>

# %%
#2. 進一步對台北市的資料做圖，以建物現況格局-房(room_number)為x軸，以總價元(total_price)為y軸畫出boxplot，並找出總價元(total_price)中位數最高的房間數。hint:資料切片找出city欄位為台北市的資料，再進一步畫圖
analysis_data.loc[analysis_data.city=='Taipei'].boxplot(column=['total_price'],by='room_number',figsize=(16,6))
# Out:
# <AxesSubplot:title={'center':'total_price'}, xlabel='room_number'>

# %%
#3. 對台北市的資料做圖，先將地區(towns)做編碼在進行，再以地區(town)為x軸，以單價元坪(unit_price_square_feet)為y軸畫出boxplot，並找出單價元坪(unit_price_square_feet)中位數最高的地區。
# hint:運用LabelEncoder()對地區(towns)做編碼，運用.inverse_transform()反查編碼的地區
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder().fit(analysis_data['towns'].values)
analysis_data['towns_2'] = le.transform(analysis_data['towns'].values)

# %%
analysis_data.loc[analysis_data['city']=='Taipei'].boxplot(column=['unit_price_square_feet'],by='towns_2',figsize=(16,6))
# Out:
# <AxesSubplot:title={'center':'unit_price_square_feet'}, xlabel='towns_2'>

# %%
le.inverse_transform([26])
# Out:
# array(['大寮區'], dtype=object)
